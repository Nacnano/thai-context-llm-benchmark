# %%
import seacrowd as sc

# %%
# List all datasets
dset_names = sc.list_datasets()

# List all datasets with their config names
dset_configs_dict = sc.list_datasets(with_config=True)

# Load a single dataset based on the dataset name
khpos_dset = sc.load_dataset("khpos", schema="seacrowd")

# Load multiple datasets based on the dataset names
dsets = sc.load_datasets(["thai_sum", "vsolscsum"], schema="seacrowd_t2t")
# Out:
#  25%|██▍       | 99/402 [00:00<00:01, 152.44it/s]
# Install the `cv2` package to use.
#  71%|███████   | 286/402 [00:08<00:03, 34.00it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 5
#       1 # List all datasets
#       2 # dset_names = sc.list_datasets()
#       3
#       4 # List all datasets with their config names
# ----> 5 dset_configs_dict = sc.list_datasets(with_config=True)
#       7 # Load a single dataset based on the dataset name
#       8 khpos_dset = sc.load_dataset("khpos", schema="seacrowd")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seacrowd\config_helper.py:1270, in list_datasets(with_config)
#    1269 def list_datasets(with_config=False):
# -> 1270     config_helper = SEACrowdConfigHelper()
#    1271     return config_helper.list_datasets(with_config=with_config)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seacrowd\config_helper.py:969, in SEACrowdConfigHelper.__init__(self, helpers, keep_broken, trust_remote_code)
#     965     continue
#     966 dataset_name = dataloader_script.stem
#     967 py_module = SourceFileLoader(
#     968     dataset_name, dataloader_script.as_posix()
# --> 969 ).load_module()
#     970 ds_module = datasets.load.dataset_module_factory(
#     971     dataloader_script.as_posix(), trust_remote_code=trust_remote_code,
#     972 )
#     973 ds_cls = datasets.load.import_main_class(ds_module.module_path)
#
# File <frozen importlib._bootstrap_external>:605, in _check_name_wrapper(self, name, *args, **kwargs)
#
# File <frozen importlib._bootstrap_external>:1120, in load_module(self, fullname)
#
# File <frozen importlib._bootstrap_external>:945, in load_module(self, fullname)
#
# File <frozen importlib._bootstrap>:290, in _load_module_shim(self, fullname)
#
# File <frozen importlib._bootstrap>:721, in _load(spec)
#
# File <frozen importlib._bootstrap>:690, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:940, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:241, in _call_with_frames_removed(f, *args, **kwds)
#
# File C:/Users/Vivobook/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/seacrowd/sea_datasets/seahorse/seahorse.py:75
#      71     return {item["gem_id"]: item["text"] for item in df[split]}
#      74 # Both train and validation splits in seahorse are taken from the validation split from the original dataset
# ---> 75 _WIKILINGUAL_DATA = {split: get_wikilingual_data("vietnamese_vi", split) for split in ["test", "validation"]}
#      76 _XLSUM_DATA = {split: get_xlsum_data("vietnamese", split) for split in ["test", "validation"]}
#      79 def get_article(gem_id, split):
#
# File C:/Users/Vivobook/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/seacrowd/sea_datasets/seahorse/seahorse.py:75, in <dictcomp>(.0)
#      71     return {item["gem_id"]: item["text"] for item in df[split]}
#      74 # Both train and validation splits in seahorse are taken from the validation split from the original dataset
# ---> 75 _WIKILINGUAL_DATA = {split: get_wikilingual_data("vietnamese_vi", split) for split in ["test", "validation"]}
#      76 _XLSUM_DATA = {split: get_xlsum_data("vietnamese", split) for split in ["test", "validation"]}
#      79 def get_article(gem_id, split):
#
# File C:/Users/Vivobook/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0/LocalCache/local-packages/Python311/site-packages/seacrowd/sea_datasets/seahorse/seahorse.py:64, in get_wikilingual_data(lang, split)
#      63 def get_wikilingual_data(lang, split):
# ---> 64     ds = datasets.load_dataset("gem", name=f"wiki_lingua_{lang}", split=split)
#      65     df = ds.to_pandas()
#      66     return dict(zip(*[df[col] for col in ["gem_id", "source"]]))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\datasets\load.py:2606, in load_dataset(path, name, data_dir, data_files, split, cache_dir, features, download_config, download_mode, verification_mode, ignore_verifications, keep_in_memory, save_infos, revision, token, use_auth_token, task, streaming, num_proc, storage_options, trust_remote_code, **config_kwargs)
#    2601 verification_mode = VerificationMode(
#    2602     (verification_mode or VerificationMode.BASIC_CHECKS) if not save_infos else VerificationMode.ALL_CHECKS
#    2603 )
#    2605 # Create a dataset builder
# -> 2606 builder_instance = load_dataset_builder(
#    2607     path=path,
#    2608     name=name,
#    2609     data_dir=data_dir,
#    2610     data_files=data_files,
#    2611     cache_dir=cache_dir,
#    2612     features=features,
#    2613     download_config=download_config,
#    2614     download_mode=download_mode,
#    2615     revision=revision,
#    2616     token=token,
#    2617     storage_options=storage_options,
#    2618     trust_remote_code=trust_remote_code,
#    2619     _require_default_config_name=name is None,
#    2620     **config_kwargs,
#    2621 )
#    2623 # Return iterable dataset in case of streaming
#    2624 if streaming:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\datasets\load.py:2277, in load_dataset_builder(path, name, data_dir, data_files, cache_dir, features, download_config, download_mode, revision, token, use_auth_token, storage_options, trust_remote_code, _require_default_config_name, **config_kwargs)
#    2275     download_config = download_config.copy() if download_config else DownloadConfig()
#    2276     download_config.storage_options.update(storage_options)
# -> 2277 dataset_module = dataset_module_factory(
#    2278     path,
#    2279     revision=revision,
#    2280     download_config=download_config,
#    2281     download_mode=download_mode,
#    2282     data_dir=data_dir,
#    2283     data_files=data_files,
#    2284     cache_dir=cache_dir,
#    2285     trust_remote_code=trust_remote_code,
#    2286     _require_default_config_name=_require_default_config_name,
#    2287     _require_custom_configs=bool(config_kwargs),
#    2288 )
#    2289 # Get dataset builder class from the processing script
#    2290 builder_kwargs = dataset_module.builder_kwargs
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\datasets\load.py:1923, in dataset_module_factory(path, revision, download_config, download_mode, dynamic_modules_path, data_dir, data_files, cache_dir, trust_remote_code, _require_default_config_name, _require_custom_configs, **download_kwargs)
#    1918             if isinstance(e1, FileNotFoundError):
#    1919                 raise FileNotFoundError(
#    1920                     f"Couldn't find a dataset script at {relative_to_absolute_path(combined_path)} or any data file in the same directory. "
#    1921                     f"Couldn't find '{path}' on the Hugging Face Hub either: {type(e1).__name__}: {e1}"
#    1922                 ) from None
# -> 1923             raise e1 from None
#    1924 else:
#    1925     raise FileNotFoundError(
#    1926         f"Couldn't find a dataset script at {relative_to_absolute_path(combined_path)} or any data file in the same directory."
#    1927     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\datasets\load.py:1896, in dataset_module_factory(path, revision, download_config, download_mode, dynamic_modules_path, data_dir, data_files, cache_dir, trust_remote_code, _require_default_config_name, _require_custom_configs, **download_kwargs)
#    1887             pass
#    1888     # Otherwise we must use the dataset script if the user trusts it
#    1889     return HubDatasetModuleFactoryWithScript(
#    1890         path,
#    1891         revision=revision,
#    1892         download_config=download_config,
#    1893         download_mode=download_mode,
#    1894         dynamic_modules_path=dynamic_modules_path,
#    1895         trust_remote_code=trust_remote_code,
# -> 1896     ).get_module()
#    1897 else:
#    1898     return HubDatasetModuleFactoryWithoutScript(
#    1899         path,
#    1900         revision=revision,
#    (...)
#    1904         download_mode=download_mode,
#    1905     ).get_module()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\datasets\load.py:1532, in HubDatasetModuleFactoryWithScript.get_module(self)
#    1525 importable_file_path = _get_importable_file_path(
#    1526     dynamic_modules_path=dynamic_modules_path,
#    1527     module_namespace="datasets",
#    1528     subdirectory_name=hash,
#    1529     name=self.name,
#    1530 )
#    1531 if not os.path.exists(importable_file_path):
# -> 1532     trust_remote_code = resolve_trust_remote_code(self.trust_remote_code, self.name)
#    1533     if trust_remote_code:
#    1534         _create_importable_file(
#    1535             local_path=local_path,
#    1536             local_imports=local_imports,
#    (...)
#    1542             download_mode=self.download_mode,
#    1543         )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\datasets\load.py:134, in resolve_trust_remote_code(trust_remote_code, repo_id)
#     131         signal.alarm(0)
#     132     except Exception:
#     133         # OS which does not support signal.SIGALRM
# --> 134         raise ValueError(
#     135             f"The repository for {repo_id} contains custom code which must be executed to correctly "
#     136             f"load the dataset. You can inspect the repository content at https://hf.co/datasets/{repo_id}.\n"
#     137             f"Please pass the argument `trust_remote_code=True` to allow custom code to be run."
#     138         )
#     139 else:
#     140     # For the CI which might put the timeout at 0
#     141     _raise_timeout_error(None, None)
#
# ValueError: The repository for gem contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at https://hf.co/datasets/gem.
# Please pass the argument `trust_remote_code=True` to allow custom code to be run.

# %%
# List all benchmarks
benchmark_names = sc.list_benchmarks()

# Load all datasets in a benchmark
seacrowd_vl_dsets = sc.load_benchmark("SEACrowd-VL")

# %%
# Load metadata of a dataloader
khpos_meta = sc.for_dataset("khpos")

# Load metadata of multiple dataloaders
meta_dsets = sc.for_datasets(["thai_sum", "vsolscsum"])

# Load metadata of a config name
nusaparagraph_meta = sc.for_config_name("nusaparagraph_emot_jav_seacrowd_text")

# Load metadata of multiple config names
meta_dsets = sc.for_config_names(["sentiment_nathasa_review_seacrowd_text", "indonli_seacrowd_pairs"])

# %%
# Load dataset from metadata
khpos_dset = khpos_meta.load_dataset()
